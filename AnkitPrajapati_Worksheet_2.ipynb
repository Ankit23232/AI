# %%
import pandas as pd
dataframe = pd.read_csv(r"/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/bank .csv")
dataframe.head(2)
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   58  management  married   tertiary      no     2143     yes   no  unknown
# 1   44  technician   single  secondary      no       29     yes   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome   y
# 0    5   may       261         1     -1         0  unknown  no
# 1    5   may       151         1     -1         0  unknown  no

# %%
import pandas as pd
dataframe = pd.read_csv(r"/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/bank .csv")
a = dataframe.tail(2)
print (a)
b = dataframe.head()
print (b)
c = dataframe.info()
print (c)
# Out:
#        age           job  marital  education default  balance housing loan  \
# 45209   57   blue-collar  married  secondary      no      668      no   no
# 45210   37  entrepreneur  married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome   y
# 45209  telephone   17   nov       508         4     -1         0  unknown  no
# 45210   cellular   17   nov       361         2    188        11    other  no
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
import pandas as pd
df.job.dtype
vankObject = df.select_dtypes(include = 'object')
df.head()
for obj in df.columns:
  columns = df[obj]
  print(f"{obj}: {columns.unique()}")
  print("")
# Out:
# age: [58 44 33 47 35 28 42 43 41 29 53 57 51 45 60 56 32 25 40 39 52 46 36 49
#  59 37 50 54 55 48 24 38 31 30 27 34 23 26 61 22 21 20 66 62 83 75 67 70
#  65 68 64 69 72 71 19 76 85 63 90 82 73 74 78 80 94 79 77 86 95 81 18 89
#  84 87 92 93 88]
#
# job: ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
#
# marital: ['married' 'single' 'divorced']
#
# education: ['tertiary' 'secondary' 'unknown' 'primary']
#
# default: ['no' 'yes']
#
# balance: [ 2143    29     2 ...  8205 14204 16353]
#
# housing: ['yes' 'no']
#
# loan: ['no' 'yes']
#
# contact: ['unknown' 'cellular' 'telephone']
#
# day: [ 5  6  7  8  9 12 13 14 15 16 19 20 21 23 26 27 28 29 30  2  3  4 11 17
#  18 24 25  1 10 22 31]
#
# month: ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
#
# duration: [ 261  151   76 ... 1298 1246 1556]
#
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/bank .csv")
null = df.isnull().sum()
print(null)
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
import pandas as pd
dataframe = pd.read_csv(r"/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/bank .csv")
bankNumericData = df.select_dtypes(exclude = 'object')
bankNumericData.to_csv("/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/banknumericdata .csv")

# %%
import pandas as pd
dataframe = pd.read_csv(r"/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/bank .csv")
df = pd.read_csv("/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/banknumericdata .csv")
df.head()
df.describe()
# Out:
#          Unnamed: 0           age        balance           day      duration  \
# count  45211.000000  45211.000000   45211.000000  45211.000000  45211.000000
# mean   22605.000000     40.936210    1362.272058     15.806419    258.163080
# std    13051.435847     10.618762    3044.765829      8.322476    257.527812
# min        0.000000     18.000000   -8019.000000      1.000000      0.000000
# 25%    11302.500000     33.000000      72.000000      8.000000    103.000000
# 50%    22605.000000     39.000000     448.000000     16.000000    180.000000
# 75%    33907.500000     48.000000    1428.000000     21.000000    319.000000
# max    45210.000000     95.000000  102127.000000     31.000000   4918.000000
#
#            campaign         pdays      previous
# count  45211.000000  45211.000000  45211.000000
# mean       2.763841     40.197828      0.580323
# std        3.098021    100.128746      2.303441
# min        1.000000     -1.000000      0.000000
# ...

# %%
import pandas as pd
dataframe = pd.read_csv(r"/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/medical_students_dataset.csv")
df = pd.read_csv

# %%
import pandas as pd
dataframe = pd.read_csv(r"/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/medical_students_dataset.csv")
null = dataframe.isnull().sum()
print(null)
# Out:
# Student ID        20000
# Age               20000
# Gender            20000
# Height            20000
# Weight            20000
# Blood Type        20000
# BMI               20000
# Temperature       20000
# Heart Rate        20000
# Blood Pressure    20000
# Cholesterol       20000
# Diabetes          20000
# Smoking           20000
# dtype: int64

# %%
import pandas as pd
dataframe = pd.read_csv(r"/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/medical_students_dataset.csv")
dataframe = dataframe.dropna(subset = 'Student ID')
dataframe = dataframe.dropna(subset = 'Gender')
dataframe = dataframe.dropna(subset = 'Blood Type')

# %%
import pandas as pd
dataframe = pd.read_csv(r"/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/medical_students_dataset.csv")
print(dataframe['Age'].unique())
# Out:
# [18. nan 32. 30. 23. 21. 28. 34. 29. 33. 24. 27. 31. 22. 25. 20. 19. 26.]

# %%
import pandas as pd
dataframe = pd.read_csv(r"/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/medical_students_dataset.csv")
dataframe['Age'] = dataframe['Age'].fillna(dataframe['Age'].mean())
dataframe['Height'] = dataframe['Height'].fillna(dataframe['Height'].mean())
dataframe['Weight'] = dataframe['Weight'].fillna(dataframe['Weight'].mean())
dataframe['Temperature'] = dataframe['Temperature'].fillna(dataframe['Temperature'].mean())
dataframe['Blood Pressure'] = dataframe['Blood Pressure'].fillna(dataframe['Blood Pressure'].mean())
dataframe['Heart Rate'] = dataframe['Heart Rate'].fillna(
dataframe['Cholestrol'] = dataframe['Cholestrol'].fillna(dataframe['Cholestrol'].mean())dataframe['Cholestrol'].mean())
# Out:
#   File "<ipython-input-37-aa9ceca25353>", line 9
#     dataframe['Cholestrol'] = dataframe['Cholestrol'].fillna(dataframe['Cholestrol'].mean())dataframe['Cholestrol'].mean())
#     ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
import pandas as pd
dataframe = pd.read_csv(r"/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/medical_students_dataset.csv")
for i in dataframe['Height']:
    dataframe["Height"] = i/100
dataframe['BMI'] = dataframe['BMI'].fillna(dataframe['Weight']/(dataframe['Height']*dataframe['Height']))
dataframe.head()
# Out:
#    Student ID   Age  Gender    Height     Weight Blood Type        BMI  \
# 0         1.0  18.0  Female  1.539274  72.354947          O  27.645835
# 1         2.0   NaN    Male  1.539274  47.630941          B  20.102832
# 2         3.0  32.0  Female  1.539274  55.741083          A  16.729017
# 3         NaN  30.0    Male  1.539274  63.332207          B  19.096042
# 4         5.0  23.0  Female  1.539274  46.234173          O  19.513320
#
#    Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking
# 0          NaN        95.0           109.0        203.0       No     NaN
# 1    98.714977        93.0           104.0        163.0       No      No
# 2    98.260293        76.0           130.0        216.0      Yes      No
# 3    98.839605        99.0           112.0        141.0       No     Yes
# 4    98.480008        95.0             NaN        231.0       No      No

# %%
import pandas as pd
dataframe = pd.read_csv(r"/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/medical_students_dataset.csv")
print(dataframe['Diabetes'].unique())
# Out:
# ['No' 'Yes' nan]

# %%
import pandas as pd
dataframe = pd.read_csv(r"/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/medical_students_dataset.csv")
dataframe['Diabetes'] =dataframe['Diabetes'].fillna('No')
dataframe['Smoking'] = dataframe['Smoking'].fillna('No')
dataframe.head()
# Out:
#    Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0         1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1         2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2         3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3         NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4         5.0  23.0  Female         NaN  46.234173          O        NaN
#
#    Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking
# 0          NaN        95.0           109.0        203.0       No      No
# 1    98.714977        93.0           104.0        163.0       No      No
# 2    98.260293        76.0           130.0        216.0      Yes      No
# 3    98.839605        99.0           112.0        141.0       No     Yes
# 4    98.480008        95.0             NaN        231.0       No      No

# %%
dataframe = pd.read_csv('/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/Titanic-Dataset.csv')
dataframe.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dataframe = pd.read_csv('/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/Titanic-Dataset.csv')
new_dataframe  = dataframe[['Name','Pclass','Sex','Age','Fare','Survived']]
new_dataframe.head()
# Out:
#                                                 Name  Pclass     Sex   Age  \
# 0                            Braund, Mr. Owen Harris       3    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female  38.0
# 2                             Heikkinen, Miss. Laina       3  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0
# 4                           Allen, Mr. William Henry       3    male  35.0
#
#       Fare  Survived
# 0   7.2500         0
# 1  71.2833         1
# 2   7.9250         1
# 3  53.1000         1
# 4   8.0500         0

# %%
dataframe = pd.read_csv('/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/Titanic-Dataset.csv')
new_dataframe['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
dataframe = pd.read_csv('/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/Titanic-Dataset.csv')
new_dataframe['Age'].isnull().sum()
new_dataframe.dropna(subset='Age')
new_dataframe.head()
# Out:
#                                                 Name  Pclass     Sex   Age  \
# 0                            Braund, Mr. Owen Harris       3    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female  38.0
# 2                             Heikkinen, Miss. Laina       3  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0
# 4                           Allen, Mr. William Henry       3    male  35.0
#
#       Fare  Survived
# 0   7.2500         0
# 1  71.2833         1
# 2   7.9250         1
# 3  53.1000         1
# 4   8.0500         0

# %%
dataframe = pd.read_csv('/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/Titanic-Dataset.csv')
if all(col in dataframe.columns for col  in ['S','C','Q']):
    print("embarked already encoded")
else:
    dataframe_encoded  = pd.get_dummies(dataframe['Embarked'], dtype=int)
    dataframe = pd.concat([dataframe,dataframe_encoded],axis='columns')
if all(em in dataframe.columns for em in ['Embarked']):
    dataframe =dataframe.drop('Embarked',axis='columns')
else:
    print("embarked already dropped")
    dataframe.head()

# %%
dataframe = pd.read_csv('/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/Titanic-Dataset.csv')
survival_rate_male = dataframe[dataframe['Sex']=="male"]['Survived'].mean()
survival_rate_female = dataframe[dataframe['Sex']=='female']['Survived'].mean()

# %%
import matplotlib.pyplot as plt
dataframe = pd.read_csv('/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/Titanic-Dataset.csv')
plt.bar(['male','female'],[survival_rate_male,survival_rate_female],color=['blue','pink'])
plt.xlabel('Sex')
plt.ylabel('Survival Rate')
plt.title('Survival Rate according to Gender')
plt.show()

# %%
dataframe = pd.read_csv('/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/Titanic-Dataset.csv')
data = {'Embarked': ['C', 'Q', 'S', 'S', 'C']}
dataframe = pd.DataFrame(data)
eem_S = dataframe['S'].mean()
em_Q= dataframe['Q'].mean()
em_C= dataframe['C'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'S'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-6e0a2c9cc6d7> in <cell line: 4>()
#       2 data = {'Embarked': ['C', 'Q', 'S', 'S', 'C']}
# ...

# %%
import matplotlib.pyplot as plt
dataframe = pd.read_csv('/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/Titanic-Dataset.csv')
plt.bar(['S','Q','C'],[em_S,em_Q,em_C],color=['lightblue','red','lightgreen'])
plt.xlabel('Port')
plt.ylabel('Survival Rate')
plt.title('Survival Rate according to Port (\'pickup point\')')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-7e12146a15b4> in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2 dataframe = pd.read_csv('/content/drive/MyDrive/Datasets-20241201T051220Z-001/Datasets/Titanic-Dataset.csv')
# ----> 3 plt.bar(['S','Q','C'],[em_S,em_Q,em_C],color=['lightblue','red','lightgreen'])
#       4 plt.xlabel('Port')
#       5 plt.ylabel('Survival Rate')
#
# NameError: name 'em_S' is not defined

# %%
dataframe['Age'].isnull().sum()
dataframe.dropna(subset='Age')
dataframe.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
age_group = pd.qcut(dataframe['Age'],q=5,labels=[1,2,3,4,5])
age_group.head()
# Out:
# 0    2
# 1    4
# 2    3
# 3    4
# 4    4
# Name: Age, dtype: category
# Categories (5, int64): [1 < 2 < 3 < 4 < 5]

# %%
age1=dataframe[dataframe['Age']==1]['Survived'].mean()
age2=dataframe[dataframe['Age']==2]['Survived'].mean()
age3=dataframe[dataframe['Age']==3]['Survived'].mean()
age4=dataframe[dataframe['Age']==4]['Survived'].mean()
age5=dataframe[dataframe['Age']==5]['Survived'].mean()

# %%
import matplotlib.pyplot as plt
plt.bar(['1','2','3','4','5'],[age1,age2,age3,age4,age5],color=['lightblue','red','lightgreen','yellow','pink'])
plt.xlabel('Age Group')
plt.ylabel('Survival Rate')
plt.title('Survival Rate according to Different Age Group')
plt.show()
